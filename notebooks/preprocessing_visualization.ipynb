# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
import joblib

preprocessor = joblib.load("../artifacts/preprocessing.joblib")

# %%
import src
print(src.__file__)
# Out:
# D:\customer-churn-prediction\src\__init__.py

# %%
filepath = r'D:\customer-churn-prediction\data\telco.csv'
df = pd.read_csv(filepath)

X = df.drop("Churn Label", axis=1)
y = df["Churn Label"]

# %%
X_transformed = preprocessor.transform(X)

# %%
X_transformed.shape
# Out:
# (7043, 8223)

# %%
print(preprocessor.feature_names_in_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(preprocessor.feature_names_in_)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:1228, in Pipeline.feature_names_in_(self)
#    1226 """Names of features seen during first step `fit` method."""
#    1227 # delegate to first step (which will call check_is_fitted)
# -> 1228 return self.steps[0][1].feature_names_in_
#
# AttributeError: 'LeakageRemover' object has no attribute 'feature_names_in_'
